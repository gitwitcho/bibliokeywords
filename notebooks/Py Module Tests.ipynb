# %%
import sys
import os

# Add the src directory to the Python path
if os.path.abspath('../src') not in sys.path:
    sys.path.insert(0, os.path.abspath('../src'))

# %%
from utilities import read_csv_files, create_biblio_folders

# create_biblio_folders('PINNs')

biblio_df = read_csv_files(project = 'PINNs', csv_dir = 'raw/scopus')

display(biblio_df)
# Out:
# 2023-05-03 12:02:51,973 - Biblio - Working directory: /Users/gilbert/Analyses/bibliometrics
# 2023-05-03 12:02:51,974 - Biblio - Reading 2 CSV files...
# /Users/gilbert/Analyses/bibliometrics/data/PINNs/raw/scopus
# File: scopus_pinn_not_oa_all.csv, Size: 1694 rows
# File: scopus_pinn_oa_all.csv, Size: 1526 rows
#                                                 Authors  \
# 0                 Tandoc C., Hu Y.-J., Qi L., Liaw P.K.
# 1                    Hijazi S., Freitag M., Landwehr N.
# 2                Chae Y.H., Kim H., Bang J., Seong P.H.
# 3                     Xiong J., Fink O., Zhou J., Ma Y.
# 4     Larvaron B., Clausel M., Bertoncello A., Benja...
# ...                                                 ...
# 3215                                        Phillips J.
# 3216                           Dennis I., Newstead S.E.
# 3217                                       Batchelor M.
# 3218                                       Taagepera R.
# ...
